# %% [markdown]
# ### Cambiar nombre de la columna 'name' por 'language_name'

# %%
# Importar librerías
import pandas as pd

# %%
# Lee el archivo CSV y lo almacena en un DataFrame de Pandas
df = pd.read_csv("../DataSet_Limpio/dataSet_limpio.csv")
df.head(3)
# Out:
#       id             title                                           overview  \
# 0    862         Toy story  Led by Woody, Andy's toys live happily in his ...
# 1   8844           Jumanji  When siblings Judy and Peter discover an encha...
# 2  15602  Grumpier old men  A family wedding reignites the ancient feud be...
#
#    popularity release_date  vote_average  vote_count    status  \
# 0   21.946943   1995-10-30           7.7      5415.0  Released
# 1   17.015539   1995-12-15           6.9      2413.0  Released
# 2   11.712900   1995-12-22           6.5        92.0  Released
#
#   original_language  runtime  ...    id_btc                   name_btc  \
# 0                en       81  ...   10194.0       Toy Story Collection
# 1                en      104  ...       NaN                        NaN
# 2                en      101  ...  119050.0  Grumpy Old Men Collection
#
#                          poster_btc                      backdrop_btc  \
# ...

# %%
# Cambiar el nombre de la columna 'name' a 'language_name'
df = df.rename(columns={'name': 'language_name'})

# %%
df.head(3)
# Out:
#       id             title                                           overview  \
# 0    862         Toy story  Led by Woody, Andy's toys live happily in his ...
# 1   8844           Jumanji  When siblings Judy and Peter discover an encha...
# 2  15602  Grumpier old men  A family wedding reignites the ancient feud be...
#
#    popularity release_date  vote_average  vote_count    status  \
# 0   21.946943   1995-10-30           7.7      5415.0  Released
# 1   17.015539   1995-12-15           6.9      2413.0  Released
# 2   11.712900   1995-12-22           6.5        92.0  Released
#
#   original_language  runtime  ...    id_btc                   name_btc  \
# 0                en       81  ...   10194.0       Toy Story Collection
# 1                en      104  ...       NaN                        NaN
# 2                en      101  ...  119050.0  Grumpy Old Men Collection
#
#                          poster_btc                      backdrop_btc  \
# ...

# %%
# df.to_csv('../DataSet_Limpio/dataSet_limpio.csv', index=False)
